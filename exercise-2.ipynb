# %% [markdown]
# # Exercise 02

# %% [markdown]
# The first cell imports the necessary modules for todays exercise. Use google to perform the tasks from the exercise sheets

# %%
import numpy as np
import pandas as pd
